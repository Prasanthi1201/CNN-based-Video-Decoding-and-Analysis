# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/dc2/dataset
# Out:
# /content/drive/MyDrive/dc2/dataset

# %%
# !wget http://data.csail.mit.edu/tofu/dataset/vimeo_triplet.zip
# Out:
# --2023-05-01 21:30:48--  http://data.csail.mit.edu/tofu/dataset/vimeo_triplet.zip
# Resolving data.csail.mit.edu (data.csail.mit.edu)... 128.52.129.40
# Connecting to data.csail.mit.edu (data.csail.mit.edu)|128.52.129.40|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34724558235 (32G) [application/zip]
# Saving to: ‘vimeo_triplet.zip.2’
#
# vimeo_triplet.zip.2   0%[                    ] 162.02M  48.0MB/s    eta 11m 55s^C

# %%
# !unzip vimeo_triplet.zip
# Out:
# Archive:  vimeo_triplet.zip
# replace vimeo_triplet/readme.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %cd /content/drive/MyDrive/dc2/dataset/UVG
# Out:
# /content/drive/MyDrive/dc2/dataset/UVG

# %%
# !wget https://ultravideo.fi/video/Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z
# Out:
# --2023-05-01 21:55:48--  https://ultravideo.fi/video/Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z
# Resolving ultravideo.fi (ultravideo.fi)... 130.230.203.118
# Connecting to ultravideo.fi (ultravideo.fi)|130.230.203.118|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 770631599 (735M)
# Saving to: ‘Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z’
#
# Jockey_1920x1080_12 100%[===================>] 734.93M  11.0MB/s    in 46s
#
# 2023-05-01 21:56:35 (15.9 MB/s) - ‘Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z’ saved [770631599/770631599]

# %%
!7z x Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z -o./
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 770631599 bytes (735 MiB)
#
# Extracting archive: Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z
# --
# Path = Jockey_1920x1080_120fps_420_8bit_YUV_RAW.7z
# Type = 7z
# Physical Size = 770631599
# Headers Size = 246
# Method = LZMA:16 BZip2
# Solid = -
# Blocks = 2
#
# Everything is Ok
#
# Files: 2
# Size:       1866240249
# Compressed: 770631599

# %%
# !apt install ffmpeg
# !pip install ffmpeg-python
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !cd /content/drive/MyDrive/dc2/dataset/UVG

# %%
# !ffmpeg -pix_fmt yuv420p -s 1920x1080 -i /content/drive/MyDrive/dc2/dataset/UVG/Jockey_1920x1080_120fps_420_8bit_YUV.yuv -vf crop=1920:1024:0:0 ./videos_crop/Jockey_1920x1080_120fps_420_8bit_YUV.yuv
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# !cd /content/drive/MyDrive/dc2/PyTorchVideoCompression-master

# %%
# !python /content/drive/MyDrive/dc2/PyTorchVideoCompression-master/PyTorchVideoCompression-master/DVC/data/UVG/convert.py

# %%
# %cd /content/drive/MyDrive/dc2/PyTorchVideoCompression-master/PyTorchVideoCompression-master/DVC/data/UVG/CreateI
# Out:
# /content/drive/MyDrive/dc2/PyTorchVideoCompression-master/PyTorchVideoCompression-master/DVC/data/UVG/CreateI

# %%
# !sh h265.sh $crf 1920 1024

# %%
# !apt-get install ffmpeg
# !pip install opencv-python
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
